# %%
import cv2
import os
import time
import uuid

# %%
IMAGES_PATH = 'Tensorflow/workspace/images/collectedimages'

# %%
labels = ['hello', 'thanks', 'yes', 'no', 'iloveyou' ]
number_imgs = 20

# %%
for label in labels:
    print(f"\nStarting collection for: '{label}'")

    # create a directory for the label if it doesn't exist..
    label_dir = os.path.join(IMAGES_PATH, label)
    os.makedirs(label_dir, exist_ok=True)

    # for turning on the webcam
    cap = cv2.VideoCapture(0)
 
    #check if webcam is working or not
    if cap.isOpened():
        print("Camera is ready.")
    else:
        print("Camera could not be opened.")
        continue 

    print("You have 5 seconds to get ready...")
    time.sleep(5)

    try:
        for img_num in range(number_imgs):
            ret, frame = cap.read()

            if not ret:
                print("Webcam failed to capture image.")
                break

            img_filename = f"{label}.{uuid.uuid1()}.jpg"
            img_path = os.path.join(label_dir, img_filename)

            cv2.imwrite(img_path, frame)

            cv2.imshow('Webcam Preview - Press Q to stop', frame)

            print(f"Saved image {img_num + 1} for '{label}' at {img_path}")

            if cv2.waitKey(2000) & 0xFF == ord('q'):
                print("Image collection interrupted by user.")
                break

    finally:

        cap.release()
        cv2.destroyAllWindows()
        print(f"Done collecting images for '{label}'.")

print("\nAll label image collection complete.")
# Out:
# Starting collection for: 'hello'
# Camera is ready.
# You have 5 seconds to get ready...
# Saved image 1 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.9273c470-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 2 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.93c67f8e-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 3 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.950cc8b2-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 4 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.963cb40e-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 5 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.976e2bb4-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 6 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.989f885c-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 7 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.99d06188-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 8 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.9b014982-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 9 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.9c33d612-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 10 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.9d64abec-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 11 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.9e94bdb8-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 12 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.9fc613b2-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 13 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.a0f738ba-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 14 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.a228daf4-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 15 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.a35ad8c8-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 16 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.a48ae9ae-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 17 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.a5bc662c-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 18 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.a6ed3422-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 19 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.a81e651e-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 20 for 'hello' at Tensorflow/workspace/images/collectedimages/hello/hello.a94f3b34-27e7-11f0-9f21-b88a609b2620.jpg
# Done collecting images for 'hello'.
#
# Starting collection for: 'thanks'
# Camera is ready.
# You have 5 seconds to get ready...
# Saved image 1 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.adda62be-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 2 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.af0b5be8-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 3 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.b03021c0-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 4 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.b15b6898-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 5 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.b28ce098-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 6 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.b3bde444-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 7 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.b4eefed4-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 8 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.b62030e8-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 9 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.b751445c-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 10 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.b88314fe-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 11 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.b9b3d39a-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 12 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.bae531e6-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 13 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.bc1613fa-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 14 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.bd4769e0-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 15 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.be789a28-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 16 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.bfa96e4a-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 17 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.c0dabf76-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 18 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.c20c12dc-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 19 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.c33dfcb0-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 20 for 'thanks' at Tensorflow/workspace/images/collectedimages/thanks/thanks.c46e7c0e-27e7-11f0-9f21-b88a609b2620.jpg
# Done collecting images for 'thanks'.
#
# Starting collection for: 'yes'
# Camera is ready.
# You have 5 seconds to get ready...
# Saved image 1 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.c8ff4636-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 2 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.ca513f8a-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 3 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.cb95582c-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 4 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.ccc675e6-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 5 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.cdf829c8-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 6 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.cf29b3ca-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 7 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.d05a2dc4-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 8 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.d18b4b7e-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 9 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.d2bc8d82-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 10 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.d3edbed8-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 11 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.d51ed094-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 12 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.d64fe0ca-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 13 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.d7812986-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 14 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.d8b32336-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 15 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.d9e3dcf0-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 16 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.db14a410-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 17 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.dc45d584-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 18 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.dd770806-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 19 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.dea85338-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 20 for 'yes' at Tensorflow/workspace/images/collectedimages/yes/yes.dfd94622-27e7-11f0-9f21-b88a609b2620.jpg
# Done collecting images for 'yes'.
#
# Starting collection for: 'no'
# Camera is ready.
# You have 5 seconds to get ready...
# Saved image 1 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.e46c0652-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 2 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.e595308a-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 3 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.e6bc11f4-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 4 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.e7e56404-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 5 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.e916b8aa-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 6 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.ea47b5a8-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 7 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.eb79166a-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 8 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.eca9b058-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 9 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.eddb3eb0-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 10 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.ef0c4ff4-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 11 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.f03d9e82-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 12 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.f16f11e6-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 13 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.f29fd348-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 14 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.f3d10b74-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 15 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.f5024616-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 16 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.f6336d58-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 17 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.f764ae8a-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 18 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.f895d356-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 19 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.f9c6fe4e-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 20 for 'no' at Tensorflow/workspace/images/collectedimages/no/no.faf89dea-27e7-11f0-9f21-b88a609b2620.jpg
# Done collecting images for 'no'.
#
# Starting collection for: 'iloveyou'
# Camera is ready.
# You have 5 seconds to get ready...
# Saved image 1 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.ff84316c-27e7-11f0-9f21-b88a609b2620.jpg
# Saved image 2 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.00b56a1a-27e8-11f0-9f21-b88a609b2620.jpg
# Saved image 3 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.01dc11dc-27e8-11f0-9f21-b88a609b2620.jpg
# Saved image 4 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.03045bc8-27e8-11f0-9f21-b88a609b2620.jpg
# Saved image 5 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.0435178a-27e8-11f0-9f21-b88a609b2620.jpg
# Saved image 6 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.056691b0-27e8-11f0-9f21-b88a609b2620.jpg
# Saved image 7 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.0697d792-27e8-11f0-9f21-b88a609b2620.jpg
# Saved image 8 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.07c8e110-27e8-11f0-9f21-b88a609b2620.jpg
# Saved image 9 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.08f9e412-27e8-11f0-9f21-b88a609b2620.jpg
# Saved image 10 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.0a2b0492-27e8-11f0-9f21-b88a609b2620.jpg
# Saved image 11 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.0b5c2c06-27e8-11f0-9f21-b88a609b2620.jpg
# Saved image 12 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.0c8d9614-27e8-11f0-9f21-b88a609b2620.jpg
# Saved image 13 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.0dbfecb2-27e8-11f0-9f21-b88a609b2620.jpg
# Saved image 14 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.0eefc5bc-27e8-11f0-9f21-b88a609b2620.jpg
# Saved image 15 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.1020e75e-27e8-11f0-9f21-b88a609b2620.jpg
# Saved image 16 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.1152584c-27e8-11f0-9f21-b88a609b2620.jpg
# Saved image 17 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.1283711a-27e8-11f0-9f21-b88a609b2620.jpg
# Saved image 18 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.13b4cd86-27e8-11f0-9f21-b88a609b2620.jpg
# Saved image 19 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.14e5847a-27e8-11f0-9f21-b88a609b2620.jpg
# Saved image 20 for 'iloveyou' at Tensorflow/workspace/images/collectedimages/iloveyou/iloveyou.1616bc9c-27e8-11f0-9f21-b88a609b2620.jpg
# Done collecting images for 'iloveyou'.
#
# All label image collection complete.
